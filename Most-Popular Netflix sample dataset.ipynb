# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("most-popular.csv")
df
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
df.tail()
# Out:
#             category  rank          show_title                  season_title  \
# 35  TV (Non-English)     6               Lupin                 Lupin: Part 2
# 36  TV (Non-English)     7    Who Killed Sara?    Who Killed Sara?: Season 1
# 37  TV (Non-English)     8  All of Us Are Dead  All of Us Are Dead: Season 1
# 38  TV (Non-English)     9          Dear Child    Dear Child: Limited Series
# 39  TV (Non-English)    10               Elite               Elite: Season 3
#
#     hours_viewed_first_91_days  runtime  views_first_91_days
# 35                   258900000   3.7833             68400000
# 36                   392400000   6.7167             58400000
# 37                   679300000  12.2333             55500000
# 38                   245400000   4.8167             50900000
# 39                   334800000   6.7000             50000000

# %%
df.shape
# Out:
# (40, 7)

# %%
df.size
# Out:
# 280

# %%
df.columns
# Out:
# Index(['category', 'rank', 'show_title', 'season_title',
#        'hours_viewed_first_91_days', 'runtime', 'views_first_91_days'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   category                    40 non-null     object
#  1   rank                        40 non-null     int64
#  2   show_title                  40 non-null     object
#  3   season_title                19 non-null     object
#  4   hours_viewed_first_91_days  40 non-null     int64
#  5   runtime                     40 non-null     float64
#  6   views_first_91_days         40 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
df.describe()
# Out:
#             rank  hours_viewed_first_91_days    runtime  views_first_91_days
# count  40.000000                4.000000e+01  40.000000         4.000000e+01
# mean    5.500000                5.194500e+08   4.759585         1.079825e+08
# std     2.908872                4.851032e+08   3.257445         5.356564e+07
# min     1.000000                8.650000e+07   1.533300         4.860000e+07
# 25%     3.000000                2.180500e+08   1.962525         6.105000e+07
# 50%     5.500000                3.300500e+08   3.133300         9.870000e+07
# 75%     8.000000                7.116750e+08   7.000025         1.363250e+08
# max    10.000000                2.205200e+09  13.066700         2.652000e+08

# %%
df['category'].value_counts()
# Out:
# Films (English)        10
# Films (Non-English)    10
# TV (English)           10
# TV (Non-English)       10
# Name: category, dtype: int64

# %%
df.isnull().sum()
# Out:
# category                       0
# rank                           0
# show_title                     0
# season_title                  21
# hours_viewed_first_91_days     0
# runtime                        0
# views_first_91_days            0
# dtype: int64

# %%
blank_values = df[df['season_title'] == 'NaN']
blank_values
df
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
df['season_title'].fillna('Aquaman-1', inplace=True)

# %%
df.isnull().sum()
# Out:
# category                      0
# rank                          0
# show_title                    0
# season_title                  0
# hours_viewed_first_91_days    0
# runtime                       0
# views_first_91_days           0
# dtype: int64

# %%
df.head()
# Out:
#           category  rank        show_title season_title  \
# 0  Films (English)     1        Red Notice    Aquaman-1
# 1  Films (English)     2     Don't Look Up    Aquaman-1
# 2  Films (English)     3  The Adam Project    Aquaman-1
# 3  Films (English)     4          Bird Box    Aquaman-1
# 4  Films (English)     5      The Gray Man    Aquaman-1
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   454200000   1.9667            230900000
# 1                   408600000   2.3833            171400000
# 2                   281000000   1.7833            157600000
# 3                   325300000   2.0667            157400000
# 4                   299500000   2.1500            139300000

# %%
df
# Out:
#                category  rank                           show_title  \
# 0       Films (English)     1                           Red Notice
# 1       Films (English)     2                        Don't Look Up
# 2       Films (English)     3                     The Adam Project
# 3       Films (English)     4                             Bird Box
# 4       Films (English)     5                         The Gray Man
# 5       Films (English)     6                     We Can Be Heroes
# 6       Films (English)     7                           The Mother
# 7       Films (English)     8    Glass Onion: A Knives Out Mystery
# 8       Films (English)     9                           Extraction
# 9       Films (English)    10                         Extraction 2
# 10  Films (Non-English)     1                                Troll
# 11  Films (Non-English)     2                              Nowhere
# 12  Films (Non-English)     3                         The Platform
# ...

# %%
df.describe()
# Out:
#             rank  hours_viewed_first_91_days    runtime  views_first_91_days
# count  40.000000                4.000000e+01  40.000000         4.000000e+01
# mean    5.500000                5.194500e+08   4.759585         1.079825e+08
# std     2.908872                4.851032e+08   3.257445         5.356564e+07
# min     1.000000                8.650000e+07   1.533300         4.860000e+07
# 25%     3.000000                2.180500e+08   1.962525         6.105000e+07
# 50%     5.500000                3.300500e+08   3.133300         9.870000e+07
# 75%     8.000000                7.116750e+08   7.000025         1.363250e+08
# max    10.000000                2.205200e+09  13.066700         2.652000e+08

# %%
import matplotlib.pyplot as plt

# Plotting the distribution of hours viewed in the first 91 days
plt.figure(figsize=(10, 6))
plt.hist(df['hours_viewed_first_91_days'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Hours Viewed in First 91 Days')
plt.xlabel('Hours Viewed')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()
